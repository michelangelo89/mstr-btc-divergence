# %% [markdown]
# # 🪙 MSTR–BTC Divergence Project: Price Exploration
# **Objective:**
# Explore and visualize the relationship between MicroStrategy (MSTR) and Bitcoin (BTC) prices from the DuckDB database.
# We'll inspect daily data, log returns, and initial correlations before moving to rolling regression and event integration.

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from src.db_utils import read_prices
px = read_prices()
px.tail()
# Out:
# ✅ Reading DB from: /workspaces/mstr-btc-divergence/data/db/mstr_btc.duckdb
#             mstr_close  btc_usd_close  ibit_close
# date
# 2025-11-06  237.199997  101301.289062         NaN
# 2025-11-07  241.929993  103372.406250         NaN
# 2025-11-08         NaN  102282.117188         NaN
# 2025-11-09         NaN  104719.640625         NaN
# 2025-11-10  238.880005  105996.593750         NaN
